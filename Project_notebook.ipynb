# %% [markdown]
# # **ETA Prediction with Machine Learning**

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# Ride-hailing apps like Uber and Yassir rely on real-time data and machine learning algorithms to automate their services. Accurately predicting the estimated time of arrival (ETA) for Yassir trips will make Yassir’s services more reliable and attractive; this will have a direct and indirect impact on both customers and business partners. The solution would help the company save money and allocate more resources to other parts of the business.
#
# The objective of this hackathon is to predict the estimated time of arrival at the dropoff point for a single Yassir journey.
#
# This project will use the [CRISP-DM](https://www.datascience-pm.com/crisp-dm-2/) framework for data science problems
#
# (Dataset : [Yassir Data](https://zindi.africa/competitions/yassir-eta-prediction-challenge-for-azubian/data))

# %% [markdown]
# ## **1. Business Understanding**

# %% [markdown]
# *Predicting Estimated Time of Arrival (ETA) for Yassir Journeys*
#
# Ride-hailing platforms such as Uber and Yassir operate in a fast-paced environment, relying on real-time data and advanced machine learning algorithms to enhance their services. In particular, accurate prediction of the Estimated Time of Arrival (ETA) for Yassir trips is crucial for improving the reliability and attractiveness of the service to both customers and business partners.
#
# ETAs are used to calculate ride fares, estimate pickup times, match riders to drivers, plan deliveries, and much more. The estimated time of arrival should be as accurate as possible. If estimate is higher then user might cancel the order or if it is lower user might complain and uninstall the app. In both cases there is loss for the company, thus making this a key metric for their business model.
#
# For several years, [Uber used gradient-boosted decision tree ensembles](https://www.uber.com/en-KE/blog/deepeta-how-uber-predicts-arrival-times/) to refine their ETA predictions. As their training dataset grew, Uber’s Apache Spark™ team contributed upstream improvements to XGBoost to allow the model to grow ever deeper, making it one of the largest and deepest XGBoost ensembles in the world at that time. They have since moved to a deep learning due to the ease of scaling on large datasets.
#
# The ETA will vary due to factors such as trip distance and/or weather-related issues.
#
# ### Objectives
# The  goal is to develop a predictive model capable of accurately estimating the time it takes for a Yassir journey to reach its drop-off point. By achieving this objective, Yassir aims to enhance the overall efficiency and quality of its service, providing tangible benefits to both customers and business partners.

# %% [markdown]
# ## **2. Data Understanding**

# %% [markdown]
# ##### **ID:** A unique identifier associated with each record in the dataset.
#
# ##### **Timestamp:** The date and time when the trip was started.
#
# ##### **Origin_lat and Origin_lon:** The geographical coordinates (latitude and longitude) of the starting point of each trip.
#
# ##### **Destination_lat and Destination_lon:** The geographical coordinates (latitude and longitude) of the destination point of each trip.
#
# ##### **Trip_distance:** The distance of the trip in in meters on a driving route.
#
# ##### **ETA (Estimated Time of Arrival):** Estimated trip time in seconds.
#
# | ID | Timestamp | Origin_lat | Origin_lon | Destination_lat | Destination_lon | Trip_distance | ETA |
# |----|-----------|------------|------------|------------------|------------------|---------------|-----|
# |Unique| Date| latitude | longitude | destinatination lat | destination long | Trip distance | ETA |

# %% [markdown]
# ### Importation
# Here is the section to import all the packages/libraries that will be used through this notebook.

# %%
#%pip install geopandas matplotlib folium
# %pip install geopy
# Out:
# Collecting geopy
#   Using cached geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Using cached geographiclib-2.0-py3-none-any.whl (40 kB)
# Using cached geopy-2.4.1-py3-none-any.whl (125 kB)
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\AD\AppData\Local\Programs\Python\Python311\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\AD\AppData\Local\Programs\Python\Python311\Lib\site-packages)
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os, joblib

# Data handling
import pandas as pd
import numpy as np

# Vizualisation
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

#EDA
import geopandas as gpd
from geopy.geocoders import Nominatim
from shapely.geometry import Point

# Feature Processing (Scikit-learn processing, etc. )
from sklearn.cluster import KMeans
from sklearn.preprocessing import PowerTransformer
import scipy.stats as stats
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, FunctionTransformer

# Machine Learning (Scikit-learn Estimators, Catboost, LightGBM, etc. )
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error, mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor

# Hyperparameters Fine-tuning (Scikit-learn hp search, cross-validation, etc. )
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### Data Loading
# Here is the section to load the datasets (train, eval, test) and the additional files

# %%
# load training data
training = pd.read_csv(r'Dataset\Train.csv').set_index('ID')
training['Timestamp'] = pd.to_datetime(training['Timestamp'])
training.head()
# Out:
#                          Timestamp  Origin_lat  Origin_lon  Destination_lat  \
# ID
# 000FLWA8 2019-12-04 20:01:50+00:00        3.26       36.78             3.00
# 000RGOAM 2019-12-10 22:37:09+00:00        3.09       36.71             3.08
# 001QSGIH 2019-11-23 20:36:10+00:00        3.14       36.74             3.09
# 002ACV6R 2019-12-01 05:43:21+00:00        3.24       36.78             3.05
# 0039Y7A8 2019-12-17 20:30:20+00:00        2.91       36.71             3.21
#
#           Destination_lon  Trip_distance   ETA
# ID
# 000FLWA8            36.72          39627  2784
# 000RGOAM            36.73           3918   576
# 001QSGIH            36.74           7265   526
# 002ACV6R            36.76          23350  3130
# 0039Y7A8            36.70          36613  2138

# %%
# testing data
testing = pd.read_csv(r'Dataset\Test.csv').set_index('ID')
testing['Timestamp'] = pd.to_datetime(testing['Timestamp'])
testing.head()
# Out:
#                          Timestamp  Origin_lat  Origin_lon  Destination_lat  \
# ID
# 000V4BQX 2019-12-21 05:52:37+00:00       2.981      36.688            2.978
# 003WBC5J 2019-12-25 21:38:53+00:00       3.032      36.769            3.074
# 004O4X3A 2019-12-29 21:30:29+00:00       3.035      36.711            3.010
# 006CEI5B 2019-12-31 22:51:57+00:00       2.902      36.738            3.208
# 009G0M2T 2019-12-28 21:47:22+00:00       2.860      36.692            2.828
#
#           Destination_lon  Trip_distance
# ID
# 000V4BQX           36.754          17549
# 003WBC5J           36.751           7532
# 004O4X3A           36.758          10194
# 006CEI5B           36.698          32768
# 009G0M2T           36.696           4513

# %%
# weather data
weather_df = pd.read_csv(r'Dataset\Weather.csv')
weather_df['date'] = pd.to_datetime(weather_df['date'])
weather_df.head()
# Out:
#         date  dewpoint_2m_temperature  maximum_2m_air_temperature  \
# 0 2019-11-01                   290.63                      296.43
# 1 2019-11-02                   289.14                      298.43
# 2 2019-11-03                   287.67                      296.61
# 3 2019-11-04                   287.63                      297.17
# 4 2019-11-05                   286.41                      294.28
#
#    mean_2m_air_temperature  mean_sea_level_pressure  \
# 0                   294.13               101,853.62
# 1                   295.55               101,225.16
# 2                   295.18               100,806.62
# 3                   294.37               101,240.93
# 4                   292.50               101,131.75
#
#    minimum_2m_air_temperature  surface_pressure  total_precipitation  \
# 0                      292.50        100,806.35                 0.00
# 1                      293.34        100,187.25                 0.00
# 2                      293.67         99,771.41                 0.00
# 3                      292.38        100,200.84                 0.00
# 4                      289.14        100,088.50                 0.00
#
#    u_component_of_wind_10m  v_component_of_wind_10m
# 0                     3.56                     0.94
# 1                     5.32                     3.26
# 2                     8.45                     3.17
# 3                     5.99                     2.24
# 4                     6.96                     2.66

# %% [markdown]
# ### Exploratory Data Analysis: EDA
# Here is the section to **inspect** the datasets in depth, **present** it, make **hypotheses** and **think** the *cleaning, processing and features creation*.

# %%
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 83924 entries, 000FLWA8 to ZZZY11ZN
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Timestamp        83924 non-null  datetime64[ns, UTC]
#  1   Origin_lat       83924 non-null  float64
#  2   Origin_lon       83924 non-null  float64
#  3   Destination_lat  83924 non-null  float64
#  4   Destination_lon  83924 non-null  float64
#  5   Trip_distance    83924 non-null  int64
#  6   ETA              83924 non-null  int64
# dtypes: datetime64[ns, UTC](1), float64(4), int64(2)
# memory usage: 5.1+ MB

# %%
#let's check if we are missing values
training.isna().sum()
# Out:
# Timestamp          0
# Origin_lat         0
# Origin_lon         0
# Destination_lat    0
# Destination_lon    0
# Trip_distance      0
# ETA                0
# dtype: int64

# %% [markdown]
# - no missing values

# %%
# format numerical columns to 2 decimal places with comma separator
pd.options.display.float_format = '{:,.2f}'.format

# statistics for numerical columns
training.describe()
# Out:
#        Origin_lat  Origin_lon  Destination_lat  Destination_lon  \
# count   83,924.00   83,924.00        83,924.00        83,924.00
# mean         3.05       36.74             3.06            36.74
# std          0.10        0.03             0.10             0.03
# min          2.81       36.59             2.81            36.60
# 25%          2.99       36.72             3.00            36.72
# 50%          3.05       36.74             3.05            36.74
# 75%          3.10       36.76             3.11            36.76
# max          3.38       36.82             3.38            36.82
#
#        Trip_distance       ETA
# count      83,924.00 83,924.00
# mean       13,527.82  1,111.70
# std         9,296.72    563.57
# min             1.00      1.00
# 25%         6,108.00    701.00
# 50%        11,731.50  1,054.00
# 75%        19,369.00  1,456.00
# max        62,028.00  5,238.00

# %% [markdown]
# - **Timestamp**: The data spans various dates in 2019.
# - **Origin and Destination Coordinates (Latitude and Longitude)**: The average coordinates are approximately 3.05 latitude and 36.74 longitude for both origin and destination. The minimum and maximum values show a limited range.
# - **Trip Distance**: The average trip distance is approximately 13,527.82 M, with a minimum of 1.00 M and a maximum of 62,028.00 M. Some anomalies with low distance.
# - **ETA (Estimated Time of Arrival)**: The average ETA is approximately 1,111.70s, with a minimum of 1.00s and a maximum of 5,238.00s. There could be some anomalies here with low ETA's.

# %% [markdown]
# #### Univariate Analysis

# %%
# Create histograms with KDE plots to visualize distribution
cols = ['Origin_lat', 'Origin_lon', 'Destination_lat', 'Destination_lon', 'Trip_distance', 'ETA']

# Calculate the number of rows needed
num_rows = len(cols) // 2 + len(cols) % 2

# Set up subplots
fig, axes = plt.subplots(nrows=num_rows, ncols=2, figsize=(12, 4 * num_rows))

# Flatten the 2D array of subplots for easier indexing
axes = axes.flatten()

# Iterate over columns and create histograms with KDE plots
for i, column in enumerate(cols):
    sns.histplot(training[column], kde=True, bins=50, color='blue', ax=axes[i])
    axes[i].set_title(f'Distribution of {column}')
    axes[i].set_xlabel(column)
    axes[i].set_ylabel('Frequency')

# Remove empty subplots if the number of subplots is odd
if len(cols) % 2 != 0:
    fig.delaxes(axes[-1])

plt.tight_layout()
plt.show()

# %% [markdown]
# - The origin and destination points seem to be in the same coordinates, indicating that the majority of the trips are likely within a single geographic area. This concentration of data in a specific zone is likely associated with internal activity within a country, potentially representing a dense urban area or a hub of economic activity.
#
# - Trip distance and ETA are positively skewed. This suggest the direction of outliers towards the upper bound of the dataset.

# %% [markdown]
# #### Bivariate Analysis

# %%
# Create a GeoDataFrame based on the origin coordinates
geometry_origin = [Point(lon, lat) for lon, lat in zip(training['Origin_lon'], training['Origin_lat'])]
gdf_origin = gpd.GeoDataFrame(training, geometry=geometry_origin, crs='EPSG:4326')

# Create a GeoDataFrame based on the destination coordinates
geometry_destination = [Point(lon, lat) for lon, lat in zip(training['Destination_lon'], training['Destination_lat'])]
gdf_destination = gpd.GeoDataFrame(training, geometry=geometry_destination, crs='EPSG:4326')

# Load the world map
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Display the world map
fig, ax = plt.subplots(figsize=(15, 15))

# Uncomment the line below if you want to plot world boundaries
# world.boundary.plot(ax=ax, linewidth=1)
ax.set_title('Distribution of Points')

# Overlay the origin and destination points
gdf_origin.plot(ax=ax, color='red', markersize=10, alpha=0.5, label='Origin')
gdf_destination.plot(ax=ax, color='blue', markersize=10, alpha=0.5, label='Destination')

# Add a legend
plt.legend()

plt.show()
# Out:
# C:\Users\AD\AppData\Local\Temp\ipykernel_20300\4218137300.py:10: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# - the visualization of the map indeed confirms the concentration of data within a specific geographic area. The proximity of the origin and destination points, along with the clustering observed on the map, aligns with the interpretation of strong local activity.

# %%
# Use the geopy locator with Nominatim/OpenStreetMaps
locator = Nominatim(user_agent='myGeoencoder')
coordinates = ['3.258,36.777'] #check the location data for one point
location = locator.reverse(coordinates)
location.raw
# Out:
# {'place_id': 68676983,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. http://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 198507881,
#  'lat': '3.2580337654742446',
#  'lon': '36.78034168388619',
#  'class': 'highway',
#  'type': 'unclassified',
#  'place_rank': 26,
#  'importance': 0.10000999999999993,
#  'addresstype': 'road',
#  'name': '',
#  'display_name': 'North Horr, Marsabit, Eastern, Kenya',
#  'address': {'village': 'North Horr',
#   'county': 'North Horr',
#   'state': 'Marsabit',
#   'ISO3166-2-lvl4': 'KE-25',
#   'country': 'Kenya',
#   'country_code': 'ke'},
#  'boundingbox': ['3.1638051', '3.3438366', '36.7788893', '36.7984563']}

# %% [markdown]
# - Our datapoints are somewhere in Marsabit state, Kenya
# - We can extract location data such as county and state with reverse geocoding

# %%
# check regression line
# Scatter plot with regression line
sns.regplot(x='Trip_distance', y='ETA', data=gdf_origin, scatter_kws={'color':'blue'}, line_kws={'color':'red'})

# Set x-axis label
plt.xlabel('Trip_distance')

# Set y-axis label
plt.ylabel('ETA')

# Set plot title
plt.title('Relationship between Trip_distance and ETA with Regression Line')

# Show the plot
plt.show()

# %% [markdown]
# The analysis of the relationship between the trip distance ('Trip_distance') and the estimated time of arrival ('ETA') indicates a significant correlation, suggesting a linear trend where longer trip distances are associated with longer arrival times. However, the presence of points deviating from the regression line suggests some variability and the possibility of atypical observations.

# %% [markdown]
# #### Multivariate Analysis

# %%
# Create a correlation matrix for continuous variables
train = training.drop('Timestamp', axis=1)
correlation_matrix = train.corr()

# Display the correlation matrix with a heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')

# Add a title
plt.title('Correlation Matrix')

# Display the plot
plt.show()

# %% [markdown]
# - ETA and trip distance have a strong positive correlation as expected. longer trips typically require more time to be covered.
# - There is also a positive relationship between origin/destination latitude and origin/destination longitude

# %% [markdown]
# ## 3. Data Preparation

# %% [markdown]
# ### Feature Processing & Engineering
# Here is the section to **clean**, **process** the dataset and **create new features**.

# %%
training.reset_index(inplace=True)
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83924 entries, 0 to 83923
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               83924 non-null  object
#  1   Timestamp        83924 non-null  datetime64[ns, UTC]
#  2   Origin_lat       83924 non-null  float64
#  3   Origin_lon       83924 non-null  float64
#  4   Destination_lat  83924 non-null  float64
#  5   Destination_lon  83924 non-null  float64
#  6   Trip_distance    83924 non-null  int64
#  7   ETA              83924 non-null  int64
# dtypes: datetime64[ns, UTC](1), float64(4), int64(2), object(1)
# memory usage: 5.1+ MB

# %%
# drop 'ID' column
training.drop(['ID'],axis=1, inplace = True)

# %% [markdown]
# #### Add speed feature

# %%
# Add 'speed' feature
training['Speed'] = training['Trip_distance'] / training['ETA'] * 3.6
training.head()
# Out:
#                   Timestamp  Origin_lat  Origin_lon  Destination_lat  \
# 0 2019-12-04 20:01:50+00:00        3.26       36.78             3.00
# 1 2019-12-10 22:37:09+00:00        3.09       36.71             3.08
# 2 2019-11-23 20:36:10+00:00        3.14       36.74             3.09
# 3 2019-12-01 05:43:21+00:00        3.24       36.78             3.05
# 4 2019-12-17 20:30:20+00:00        2.91       36.71             3.21
#
#    Destination_lon  Trip_distance   ETA  Speed
# 0            36.72          39627  2784  51.24
# 1            36.73           3918   576  24.49
# 2            36.74           7265   526  49.72
# 3            36.76          23350  3130  26.86
# 4            36.70          36613  2138  61.65

# %%
# Histogram of the speed column with x-axis limit
plt.hist(training['Speed'], bins=50, color='skyblue', edgecolor='black', range=[0, 100])
plt.title('Speed Distribution')
plt.xlabel('Speed (Km/h)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# We observe a concentration of speed between 20 and 60, indicating that most observations have speeds within this range. This suggests that the majority of trips in our dataset occur at relatively low-average speeds.

# %% [markdown]
# #### Merge training data and weather data

# %%
# Merge 'Weather' and 'training' on date column

training['date']=training['Timestamp'].dt.date
training['date']=pd.to_datetime(training['date'])
training_merged=pd.merge(training,weather_df, how='left', on='date')
print(training_merged.shape)
training_merged.head()
# Out:
# (83924, 18)
#                   Timestamp  Origin_lat  Origin_lon  Destination_lat  \
# 0 2019-12-04 20:01:50+00:00        3.26       36.78             3.00
# 1 2019-12-10 22:37:09+00:00        3.09       36.71             3.08
# 2 2019-11-23 20:36:10+00:00        3.14       36.74             3.09
# 3 2019-12-01 05:43:21+00:00        3.24       36.78             3.05
# 4 2019-12-17 20:30:20+00:00        2.91       36.71             3.21
#
#    Destination_lon  Trip_distance   ETA  Speed       date  \
# 0            36.72          39627  2784  51.24 2019-12-04
# 1            36.73           3918   576  24.49 2019-12-10
# 2            36.74           7265   526  49.72 2019-11-23
# 3            36.76          23350  3130  26.86 2019-12-01
# 4            36.70          36613  2138  61.65 2019-12-17
#
#    dewpoint_2m_temperature  maximum_2m_air_temperature  \
# 0                   283.05                      288.32
# 1                   282.29                      289.17
# 2                   284.37                      292.54
# 3                   284.53                      292.35
# 4                   281.46                      292.58
#
#    mean_2m_air_temperature  mean_sea_level_pressure  \
# 0                   286.98               100,523.06
# 1                   286.99               102,472.15
# 2                   289.94               100,172.91
# 3                   288.69               101,382.91
# 4                   291.20               100,634.46
#
#    minimum_2m_air_temperature  surface_pressure  total_precipitation  \
# 0                      286.00         99,474.22                 0.01
# 1                      283.80        101,401.24                 0.00
# 2                      287.65         99,133.38                 0.01
# 3                      285.94        100,338.46                 0.00
# 4                      287.55         99,595.82                 0.00
#
#    u_component_of_wind_10m  v_component_of_wind_10m
# 0                     1.91                     2.44
# 1                     2.55                    -1.54
# 2                     6.64                     3.55
# 3                    -0.08                     1.09
# 4                    -1.77                     2.67

# %% [markdown]
# #### Extract date-time features

# %%
def add_date_features(df,timestamp_id):

    df.loc[:, 'pickup_weekday'] = df[timestamp_id].dt.weekday
    df.loc[:, 'pickup_weekofyear'] = df[timestamp_id].dt.isocalendar().week
    df.loc[:, 'pickup_hour'] = df[timestamp_id].dt.hour
    df.loc[:, 'pickup_minute'] = df[timestamp_id].dt.minute
    df.loc[:, 'pickup_week_hour'] = df['pickup_weekday'] * 24 + df['pickup_hour']
    df['month']=df[timestamp_id].dt.month
    df['day_of_week']=df[timestamp_id].dt.dayofweek
    df['day_of_year']=df[timestamp_id].dt.dayofyear

# %%
add_date_features(training_merged,'Timestamp')

# %%
training_merged.head()
# Out:
#                   Timestamp  Origin_lat  Origin_lon  Destination_lat  \
# 0 2019-12-04 20:01:50+00:00        3.26       36.78             3.00
# 1 2019-12-10 22:37:09+00:00        3.09       36.71             3.08
# 2 2019-11-23 20:36:10+00:00        3.14       36.74             3.09
# 3 2019-12-01 05:43:21+00:00        3.24       36.78             3.05
# 4 2019-12-17 20:30:20+00:00        2.91       36.71             3.21
#
#    Destination_lon  Trip_distance   ETA  Speed       date  \
# 0            36.72          39627  2784  51.24 2019-12-04
# 1            36.73           3918   576  24.49 2019-12-10
# 2            36.74           7265   526  49.72 2019-11-23
# 3            36.76          23350  3130  26.86 2019-12-01
# 4            36.70          36613  2138  61.65 2019-12-17
#
#    dewpoint_2m_temperature  ...  u_component_of_wind_10m  \
# 0                   283.05  ...                     1.91
# 1                   282.29  ...                     2.55
# 2                   284.37  ...                     6.64
# 3                   284.53  ...                    -0.08
# 4                   281.46  ...                    -1.77
#
#    v_component_of_wind_10m  pickup_weekday  pickup_weekofyear  pickup_hour  \
# 0                     2.44               2                 49           20
# 1                    -1.54               1                 50           22
# 2                     3.55               5                 47           20
# 3                     1.09               6                 48            5
# 4                     2.67               1                 51           20
#
#    pickup_minute  pickup_week_hour  month  day_of_week  day_of_year
# 0              1                68     12            2          338
# 1             37                46     12            1          344
# 2             36               140     11            5          327
# 3             43               149     12            6          335
# 4             30                44     12            1          351
#
# [5 rows x 26 columns]

# %% [markdown]
# #### Handle Outliers

# %% [markdown]
# - Outliers have a big effect on rmse score

# %%
# Check for outliers in the numerical variables
# Use boxplot

for col in ['ETA','Trip_distance','Speed']:
    print(col)
    plt.boxplot(training_merged[col])
    plt.show()
# Out:
# ETA
# Trip_distance
# Speed

# %%
#Function to detect and remove outliers
def remove_outliers(data, columns, threshold=1.5):
    """
    Remove outliers from numerical columns using the Interquartile Range (IQR) method.

    Parameters:
    - data: DataFrame, the input DataFrame.
    - columns: list, the list of numerical columns for which outliers should be removed.
    - threshold: float, the threshold to determine outliers (default is 1.5).

    Returns:
    - DataFrame, the DataFrame without outliers in the specified columns.
    """

    data_no_outliers = training_merged.copy()

    for column in columns:
        # Calculate the IQR for the column
        q1 = data_no_outliers[column].quantile(0.25)
        q3 = data_no_outliers[column].quantile(0.75)
        iqr = q3 - q1

        # Define the lower and upper bounds for outliers
        lower_bound = q1 - threshold * iqr
        upper_bound = q3 + threshold * iqr

        # Remove outliers
        data_no_outliers = data_no_outliers[(data_no_outliers[column] >= lower_bound) & (data_no_outliers[column] <= upper_bound)]

    return data_no_outliers

# %%
# numeric_columns = ['ETA', 'Speed', 'Trip_distance']
# training_merged = remove_outliers(training_merged, numeric_columns)
training_merged = training_merged.reset_index(drop=True)

# %%
training_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83924 entries, 0 to 83923
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Timestamp                   83924 non-null  datetime64[ns, UTC]
#  1   Origin_lat                  83924 non-null  float64
#  2   Origin_lon                  83924 non-null  float64
#  3   Destination_lat             83924 non-null  float64
#  4   Destination_lon             83924 non-null  float64
#  5   Trip_distance               83924 non-null  int64
#  6   ETA                         83924 non-null  int64
#  7   Speed                       83924 non-null  float64
#  8   date                        83924 non-null  datetime64[ns]
#  9   dewpoint_2m_temperature     83924 non-null  float64
#  10  maximum_2m_air_temperature  83924 non-null  float64
#  11  mean_2m_air_temperature     83924 non-null  float64
#  12  mean_sea_level_pressure     83924 non-null  float64
#  13  minimum_2m_air_temperature  83924 non-null  float64
#  14  surface_pressure            83924 non-null  float64
#  15  total_precipitation         83924 non-null  float64
#  16  u_component_of_wind_10m     83924 non-null  float64
#  17  v_component_of_wind_10m     83924 non-null  float64
#  18  pickup_weekday              83924 non-null  int32
#  19  pickup_weekofyear           83924 non-null  UInt32
#  20  pickup_hour                 83924 non-null  int32
#  21  pickup_minute               83924 non-null  int32
#  22  pickup_week_hour            83924 non-null  int32
#  23  month                       83924 non-null  int32
#  24  day_of_week                 83924 non-null  int32
#  25  day_of_year                 83924 non-null  int32
# dtypes: UInt32(1), datetime64[ns, UTC](1), datetime64[ns](1), float64(14), int32(7), int64(2)
# memory usage: 14.2 MB

# %% [markdown]
# #### handle missing values

# %%
#check missing values
training_merged.isna().sum()
# Out:
# Timestamp                     0
# Origin_lat                    0
# Origin_lon                    0
# Destination_lat               0
# Destination_lon               0
# Trip_distance                 0
# ETA                           0
# Speed                         0
# date                          0
# dewpoint_2m_temperature       0
# maximum_2m_air_temperature    0
# mean_2m_air_temperature       0
# mean_sea_level_pressure       0
# minimum_2m_air_temperature    0
# surface_pressure              0
# total_precipitation           0
# u_component_of_wind_10m       0
# v_component_of_wind_10m       0
# pickup_weekday                0
# pickup_weekofyear             0
# pickup_hour                   0
# pickup_minute                 0
# pickup_week_hour              0
# month                         0
# day_of_week                   0
# day_of_year                   0
# dtype: int64

# %% [markdown]
# #### handle duplicate values

# %%
#check for duplicates
training_merged.duplicated().sum()
# Out:
# 158

# %%
training_merged = training_merged.set_index('Timestamp')
training_merged.sort_index(ascending=True, inplace=True)

# %%
# show all occurences of duplicated rows
training_merged[training_merged.duplicated(keep=False)]
# Out:
#                            Origin_lat  Origin_lon  Destination_lat  \
# Timestamp
# 2019-11-19 23:04:03+00:00        3.01       36.78             3.21
# 2019-11-19 23:04:12+00:00        3.01       36.78             3.21
# 2019-11-19 23:38:14+00:00        2.90       36.80             2.89
# 2019-11-19 23:38:14+00:00        2.90       36.80             2.89
# 2019-11-19 23:46:58+00:00        2.85       36.68             3.05
# ...                               ...         ...              ...
# 2019-12-19 23:19:36+00:00        2.97       36.76             3.19
# 2019-12-19 23:19:43+00:00        2.97       36.76             3.19
# 2019-12-19 23:19:46+00:00        2.97       36.76             3.19
# 2019-12-19 23:19:47+00:00        2.97       36.76             3.19
# 2019-12-19 23:19:51+00:00        2.97       36.76             3.19
#
#                            Destination_lon  Trip_distance   ETA  Speed  \
# Timestamp
# 2019-11-19 23:04:03+00:00            36.70          24652  1589  55.85
# 2019-11-19 23:04:12+00:00            36.70          24652  1589  55.85
# 2019-11-19 23:38:14+00:00            36.75           6670   795  30.20
# 2019-11-19 23:38:14+00:00            36.75           6670   795  30.20
# 2019-11-19 23:46:58+00:00            36.78          26065  1678  55.92
# ...                                    ...            ...   ...    ...
# 2019-12-19 23:19:36+00:00            36.73          30512  1683  65.27
# 2019-12-19 23:19:43+00:00            36.73          30512  1683  65.27
# 2019-12-19 23:19:46+00:00            36.73          30512  1683  65.27
# 2019-12-19 23:19:47+00:00            36.73          30512  1683  65.27
# 2019-12-19 23:19:51+00:00            36.73          30512  1683  65.27
#
#                                 date  dewpoint_2m_temperature  \
# Timestamp
# 2019-11-19 23
# 2019-12-19 23:19:36+00:00             19                95     12
# 2019-12-19 23:19:43+00:00             19                95     12
# 2019-12-19 23:19:46+00:00             19                95     12
# 2019-12-19 23:19:47+00:00             19                95     12
# 2019-12-19 23:19:51+00:00             19                95     12
#
#                            day_of_week  day_of_year
# Timestamp
# 2019-11-19 23:04:03+00:00            1          323
# 2019-11-19 23:04:12+00:00            1          323
# 2019-11-19 23:38:14+00:00            1          323
# 2019-11-19 23:38:14+00:00            1          323
# 2019-11-19 23:46:58+00:00            1          323
# ...                                ...          ...
# 2019-12-19 23:19:36+00:00            3          353
# 2019-12-19 23:19:43+00:00            3          353
# 2019-12-19 23:19:46+00:00            3          353
# 2019-12-19 23:19:47+00:00            3          353
# 2019-12-19 23:19:51+00:00            3          353
#
# [2155 rows x 25 columns]

# %%
# Drop duplicates
training_merged.drop_duplicates(inplace = True)

# %%
training_merged = training_merged.reset_index()
training_merged.head()
# Out:
#                   Timestamp  Origin_lat  Origin_lon  Destination_lat  \
# 0 2019-11-19 23:00:08+00:00        3.02       36.75             3.03
# 1 2019-11-19 23:00:10+00:00        2.97       36.76             3.01
# 2 2019-11-19 23:00:38+00:00        2.85       36.68             3.05
# 3 2019-11-19 23:00:44+00:00        2.98       36.76             3.00
# 4 2019-11-19 23:00:53+00:00        2.86       36.76             3.19
#
#    Destination_lon  Trip_distance   ETA  Speed       date  \
# 0            36.77           3898   556  25.24 2019-11-19
# 1            36.73           5861   785  26.88 2019-11-19
# 2            36.78          26065  1661  56.49 2019-11-19
# 3            36.78           4943   629  28.29 2019-11-19
# 4            36.72          37492  2181  61.89 2019-11-19
#
#    dewpoint_2m_temperature  ...  u_component_of_wind_10m  \
# 0                   281.22  ...                     3.20
# 1                   281.22  ...                     3.20
# 2                   281.22  ...                     3.20
# 3                   281.22  ...                     3.20
# 4                   281.22  ...                     3.20
#
#    v_component_of_wind_10m  pickup_weekday  pickup_weekofyear  pickup_hour  \
# 0                     0.88               1                 47           23
# 1                     0.88               1                 47           23
# 2                     0.88               1                 47           23
# 3                     0.88               1                 47           23
# 4                     0.88               1                 47           23
#
#    pickup_minute  pickup_week_hour  month  day_of_week  day_of_year
# 0              0                47     11            1          323
# 1              0                47     11            1          323
# 2              0                47     11            1          323
# 3              0                47     11            1          323
# 4              0                47     11            1          323
#
# [5 rows x 26 columns]

# %% [markdown]
# #### Clustering coordinates

# %%
# Elbow method to find best k clusters

coords = training_merged[['Origin_lat'	,'Origin_lon'	,'Destination_lat'	,'Destination_lon']]

# Assuming data is your feature matrix
inertias = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(coords)
    inertias.append(kmeans.inertia_)

# Plotting the Elbow Method
plt.plot(range(1, 11), inertias, marker='o')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal k')
plt.show()
# Out:
# C:\Users\AD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\AD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\AD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\AD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\AD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\AD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\AD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\AD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\AD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\AD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# - Graph shows elbow at K=2, however it is not clear enough. In this case we will use our max=10

# %%
#trip clustering
kmean=KMeans(n_clusters=10,random_state= 0)

training_merged["cluster_id"]=kmean.fit_predict(coords)
# Out:
# C:\Users\AD\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
training_merged.head()
# Out:
#                   Timestamp  Origin_lat  Origin_lon  Destination_lat  \
# 0 2019-11-19 23:00:08+00:00        3.02       36.75             3.03
# 1 2019-11-19 23:00:10+00:00        2.97       36.76             3.01
# 2 2019-11-19 23:00:38+00:00        2.85       36.68             3.05
# 3 2019-11-19 23:00:44+00:00        2.98       36.76             3.00
# 4 2019-11-19 23:00:53+00:00        2.86       36.76             3.19
#
#    Destination_lon  Trip_distance   ETA  Speed       date  \
# 0            36.77           3898   556  25.24 2019-11-19
# 1            36.73           5861   785  26.88 2019-11-19
# 2            36.78          26065  1661  56.49 2019-11-19
# 3            36.78           4943   629  28.29 2019-11-19
# 4            36.72          37492  2181  61.89 2019-11-19
#
#    dewpoint_2m_temperature  ...  v_component_of_wind_10m  pickup_weekday  \
# 0                   281.22  ...                     0.88               1
# 1                   281.22  ...                     0.88               1
# 2                   281.22  ...                     0.88               1
# 3                   281.22  ...                     0.88               1
# 4                   281.22  ...                     0.88               1
#
#    pickup_weekofyear  pickup_hour  pickup_minute  pickup_week_hour  month  \
# 0                 47           23              0                47     11
# 1                 47           23              0                47     11
# 2                 47           23              0                47     11
# 3                 47           23              0                47     11
# 4                 47           23              0                47     11
#
#    day_of_week  day_of_year  cluster_id
# 0            1          323           6
# 1            1          323           2
# 2            1          323           0
# 3            1          323           2
# 4            1          323           3
#
# [5 rows x 27 columns]

# %% [markdown]
# #### Transform target variable

# %%
target = training_merged["ETA"]
sns.distplot(target)
print("skewness : ",stats.skew(target.values))
# Out:
# C:\Users\AD\AppData\Local\Temp\ipykernel_20300\3181792633.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(target)
# skewness :  0.694004509504016

# %%
# Reshape the target variable with PowerTransformer
target = target.values.reshape(-1, 1)

# Create and fit the PowerTransformer with boxcox method
boxcox_transformer = PowerTransformer(method='box-cox', standardize=False)
target_transformed = boxcox_transformer.fit_transform(target)

# Plot the distribution of the transformed target variable
sns.distplot(target_transformed)
print("Skewness after Box-Cox transformation:", stats.skew(target_transformed))
# Out:
# C:\Users\AD\AppData\Local\Temp\ipykernel_20300\1576812632.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(target_transformed)
# Skewness after Box-Cox transformation: [-0.00514375]

# %%
# training_merged['target_transformed'] = target_transformed
# training_merged.head()

# %%
#drop columns
training_merged = training_merged.drop(columns= ['date', 'surface_pressure']
              ,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 2
#       1 #drop columns
# ----> 2 training_merged = training_merged.drop(columns= ['date', 'surface_pressure']
#       3               ,axis=1)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['date', 'surface_pressure'] not found in axis"

# %%
# Add weather features

# temperature_range
training_merged['temperature_range'] = training_merged['maximum_2m_air_temperature'] - training_merged['minimum_2m_air_temperature']

# Calculate wind speed
training_merged['wind_speed'] = np.sqrt(training_merged['u_component_of_wind_10m']**2 + training_merged['v_component_of_wind_10m']**2)

# Rain
training_merged['rain'] = (training_merged['total_precipitation'] > 0).astype(int)

# %%
training_merged = training_merged.drop(columns= ['u_component_of_wind_10m', 'v_component_of_wind_10m'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 training_merged = training_merged.drop(columns= ['u_component_of_wind_10m', 'v_component_of_wind_10m'],axis=1)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
#    5266     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4549, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547 for axis, labels in axes.items():
#    4548     if labels is not None:
# -> 4549         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4551 if inplace:
#    4552     self._update_inplace(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4591, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4589         new_axis = axis.drop(labels, level=level, errors=errors)
#    4590     else:
# -> 4591         new_axis = axis.drop(labels, errors=errors)
#    4592     indexer = axis.get_indexer(new_axis)
#    4594 # Case for non-unique axis
#    4595 else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6699, in Index.drop(self, labels, errors)
#    6697 if mask.any():
#    6698     if errors != "ignore":
# -> 6699         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6700     indexer = indexer[~mask]
#    6701 return self.delete(indexer)
#
# KeyError: "['u_component_of_wind_10m', 'v_component_of_wind_10m'] not found in axis"

# %%
training_merged.head()
# Out:
#                   Timestamp  Origin_lat  Origin_lon  Destination_lat  \
# 0 2019-11-19 23:00:08+00:00        3.02       36.75             3.03
# 1 2019-11-19 23:00:10+00:00        2.97       36.76             3.01
# 2 2019-11-19 23:00:38+00:00        2.85       36.68             3.05
# 3 2019-11-19 23:00:44+00:00        2.98       36.76             3.00
# 4 2019-11-19 23:00:53+00:00        2.86       36.76             3.19
#
#    Destination_lon  Trip_distance   ETA  Speed  dewpoint_2m_temperature  \
# 0            36.77           3898   556  25.24                   281.22
# 1            36.73           5861   785  26.88                   281.22
# 2            36.78          26065  1661  56.49                   281.22
# 3            36.78           4943   629  28.29                   281.22
# 4            36.72          37492  2181  61.89                   281.22
#
#    maximum_2m_air_temperature  ...  pickup_hour  pickup_minute  \
# 0                      288.50  ...           23              0
# 1                      288.50  ...           23              0
# 2                      288.50  ...           23              0
# 3                      288.50  ...           23              0
# 4                      288.50  ...           23              0
#
#    pickup_week_hour  month  day_of_week  day_of_year  cluster_id  \
# 0                47     11            1          323           6
# 1                47     11            1          323           2
# 2                47     11            1          323           0
# 3                47     11            1          323           2
# 4                47     11            1          323           3
#
#    temperature_range  wind_speed  rain
# 0               5.64        3.32     1
# 1               5.64        3.32     1
# 2               5.64        3.32     1
# 3               5.64        3.32     1
# 4               5.64        3.32     1
#
# [5 rows x 28 columns]

# %%
#drop columns
training_merged = training_merged.drop(columns= ['u_component_of_wind_10m', 'v_component_of_wind_10m'],axis=1)

# %%
training_merged = training_merged.set_index('Timestamp')
training_merged.sort_index(ascending=True, inplace=True)
training_merged.head()
# Out:
#                            Origin_lat  Origin_lon  Destination_lat  \
# Timestamp
# 2019-11-19 23:00:08+00:00        3.02       36.75             3.03
# 2019-11-19 23:00:10+00:00        2.97       36.76             3.01
# 2019-11-19 23:00:38+00:00        2.85       36.68             3.05
# 2019-11-19 23:00:44+00:00        2.98       36.76             3.00
# 2019-11-19 23:00:53+00:00        2.86       36.76             3.19
#
#                            Destination_lon  Trip_distance   ETA  Speed  \
# Timestamp
# 2019-11-19 23:00:08+00:00            36.77           3898   556  25.24
# 2019-11-19 23:00:10+00:00            36.73           5861   785  26.88
# 2019-11-19 23:00:38+00:00            36.78          26065  1661  56.49
# 2019-11-19 23:00:44+00:00            36.78           4943   629  28.29
# 2019-11-19 23:00:53+00:00            36.72          37492  2181  61.89
#
#                            dewpoint_2m_temperature  \
# Timestamp
# 2019-11-19 23:00:08+00:00                   281.22
# 2019-11-19 23:00:10+00:00                   281.22
# 2019-11-19 23:00:38+00:00                   281.22
# 2019-11-19 23:00:44+00:00                   281.22
# 2019-11-19 23:00:53+00:00                   281.22
#
#                            maximum_2m_air_temperature  \
# Timestamp
# 2019-11-19 23:00:08+00:00                      288.50
# 2019-11-19 23:00:10+00:00                      288.50
# 2019-11-19 23:00:38+00:00                      288.50
# 2019-11-19 23:00:44+00:00                      288.50
# 2019-11-19 23:00:53+00:00                      288.50
#
#                            mean_2m_air_temperature  ...  pickup_hour  \
# Timestamp                                           ...
# 2019-11-19 23:00:08+00:00                   285.20  ...           23
# 2019-11-19 23:00:10+00:00                   285.20  ...           23
# 2019-11-19 23:00:38+00:00                   285.20  ...           23
# 2019-11-19 23:00:44+00:00                   285.20  ...           23
# 2019-11-19 23:00:53+00:00                   285.20  ...           23
#
#                            pickup_minute  pickup_week_hour  month  \
# Timestamp
# 2019-11-19 23:00:08+00:00              0                47     11
# 2019-11-19 23:00:10+00:00              0                47     11
# 2019-11-19 23:00:38+00:00              0                47     11
# 2019-11-19 23:00:44+00:00              0                47     11
# 2019-11-19 23:00:53+00:00              0                47     11
#
#                            day_of_week  day_of_year  cluster_id  \
# Timestamp
# 2019-11-19 23:00:08+00:00            1          323           6
# 2019-11-19 23:00:10+00:00            1          323           2
# 2019-11-19 23:00:38+00:00            1          323           0
# 2019-11-19 23:00:44+00:00            1          323           2
# 2019-11-19 23:00:53+00:00            1          323           3
#
#                            temperature_range  wind_speed  rain
# Timestamp
# 2019-11-19 23:00:08+00:00               5.64        3.32     1
# 2019-11-19 23:00:10+00:00               5.64        3.32     1
# 2019-11-19 23:00:38+00:00               5.64        3.32     1
# 2019-11-19 23:00:44+00:00               5.64        3.32     1
# 2019-11-19 23:00:53+00:00               5.64        3.32     1
#
# [5 rows x 25 columns]

# %%
training_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 82811 entries, 2019-11-19 23:00:08+00:00 to 2019-12-19 23:59:29+00:00
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Origin_lat                  82811 non-null  float64
#  1   Origin_lon                  82811 non-null  float64
#  2   Destination_lat             82811 non-null  float64
#  3   Destination_lon             82811 non-null  float64
#  4   Trip_distance               82811 non-null  int64
#  5   ETA                         82811 non-null  int64
#  6   Speed                       82811 non-null  float64
#  7   dewpoint_2m_temperature     82811 non-null  float64
#  8   maximum_2m_air_temperature  82811 non-null  float64
#  9   mean_2m_air_temperature     82811 non-null  float64
#  10  mean_sea_level_pressure     82811 non-null  float64
#  11  minimum_2m_air_temperature  82811 non-null  float64
#  12  total_precipitation         82811 non-null  float64
#  13  pickup_weekday              82811 non-null  int32
#  14  pickup_weekofyear           82811 non-null  UInt32
#  15  pickup_hour                 82811 non-null  int32
#  16  pickup_minute               82811 non-null  int32
#  17  pickup_week_hour            82811 non-null  int32
# minimum_2m_air_temperature 82,811.00     285.69     1.32     282.35
# total_precipitation        82,811.00       0.00     0.00      -0.00
# pickup_weekday             82,811.00       3.00     1.90       0.00
# pickup_weekofyear          82,811.00      48.85     1.30      47.00
# pickup_hour                82,811.00      15.31     8.78       0.00
# pickup_minute              82,811.00      28.85    17.52       0.00
# pickup_week_hour           82,811.00      87.40    46.25       0.00
# month                      82,811.00      11.60     0.49      11.00
# day_of_week                82,811.00       3.00     1.90       0.00
# day_of_year                82,811.00     337.94     8.70     323.00
# cluster_id                 82,811.00       4.69     2.80       0.00
# temperature_range          82,811.00       5.65     1.83       2.08
# wind_speed                 82,811.00       3.61     2.20       0.80
# rain                       82,811.00       0.83     0.38       0.00
#
#                                   25%        50%        75%        max
# Origin_lat                       2.99       3.05       3.10       3.38
# Origin_lon                      36.72      36.74      36.76      36.82
# Destination_lat                  3.00       3.05       3.11       3.38
# Destination_lon                 36.72      36.74      36.76      36.82
# Trip_distance                6,103.50  11,730.00  19,373.00  62,028.00
# ETA                            700.00   1,054.00   1,457.00   5,238.00
# Speed                           29.23      40.17      51.07   5,562.00
# dewpoint_2m_temperature        282.50     283.76     284.88     286.33
# maximum_2m_air_temperature     290.31     291.37     292.54     294.42
# mean_2m_air_temperature        287.43     288.46     289.74     291.59
# mean_sea_level_pressure    101,204.84 101,586.09 102,011.88 102,472.15
# minimum_2m_air_temperature     285.04     285.60     286.30     287.69
# total_precipitation              0.00       0.00       0.00       0.01
# pickup_weekday                   1.00       3.00       5.00       6.00
# pickup_weekofyear               48.00      49.00      50.00      51.00
# pickup_hour                      5.00      20.00      22.00      23.00
# pickup_minute                   13.00      29.00      44.00      59.00
# pickup_week_hour                47.00      92.00     120.00     167.00
# month                           11.00      12.00      12.00      12.00
# day_of_week                      1.00       3.00       5.00       6.00
# day_of_year                    331.00     338.00     345.00     353.00
# cluster_id                       2.00       5.00       7.00       9.00
# temperature_range                4.89       5.85       6.69       9.17
# wind_speed                       2.07       3.01       4.99       9.89
# rain                             1.00       1.00       1.00       1.00

# %%
#Remove some anomalies

eta_filter = (training_merged['ETA'] <10)

trip_distance_filter = (
    (training_merged['Trip_distance'] < 10) | ((training_merged['Trip_distance']<10) & (training_merged['ETA']<60))
)

#Apply the filter separately
training_merged = training_merged.drop(training_merged[eta_filter].index)
training_merged = training_merged.drop(training_merged[trip_distance_filter].index)
training_merged.describe()
# Out:
# C:\Users\AD\AppData\Local\Temp\ipykernel_20300\1743903404.py:11: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   training_merged = training_merged.drop(training_merged[trip_distance_filter].index)
#        Origin_lat  Origin_lon  Destination_lat  Destination_lon  \
# count   82,582.00   82,582.00        82,582.00        82,582.00
# mean         3.05       36.74             3.06            36.74
# std          0.10        0.03             0.10             0.03
# min          2.81       36.59             2.81            36.60
# 25%          2.99       36.72             3.00            36.72
# 50%          3.05       36.74             3.05            36.74
# 75%          3.10       36.76             3.11            36.76
# max          3.38       36.82             3.38            36.82
#
#        Trip_distance       ETA     Speed  dewpoint_2m_temperature  \
# count      82,582.00 82,582.00 82,582.00                82,582.00
# mean       13,559.59  1,114.39     40.32                   283.66
# std         9,287.36    561.89     14.18                     1.78
# min             3.00     10.00      0.33                   279.52
# 25%         6,140.00    703.00     29.28                   282.50
# 50%        11,759.00  1,056.50     40.21                   283.76
# 75%        19,388.00  1,458.00     51.08                   284.88
# max        62,028.00  5,238.00    499.68                   286.33
#
#        maximum_2m_air_temperature  mean_2m_air_temperature  ...  pickup_hour  \
# count                   82,582.00                82,582.00  ...    82,582.00
# mean                       291.34                   288.56  ...        15.31
# std                          1.65                     1.35  ...         8.78
# min                        288.20                   285.20  ...         0.00
# 25%                        290.31                   287.43  ...         5.00
# 50%                        291.37                   288.46  ...        20.00
# 75%                        292.54                   289.74  ...        22.00
# max                        294.42                   291.59  ...        23.00
#
#        pickup_minute  pickup_week_hour     month  day_of_week  day_of_year  \
# count      82,582.00         82,582.00 82,582.00    82,582.00    82,582.00
# mean           28.85             87.38     11.60         3.00       337.94
# std            17.51             46.25      0.49         1.90         8.70
# min             0.00              0.00     11.00         0.00       323.00
# 25%            13.00             47.00     11.00         1.00       331.00
# 50%            29.00             92.00     12.00         3.00       338.00
# 75%            44.00            120.00     12.00         5.00       345.00
# max            59.00            167.00     12.00         6.00       353.00
#
#        cluster_id  temperature_range  wind_speed      rain
# count   82,582.00          82,582.00   82,582.00 82,582.00
# mean         4.69               5.65        3.61      0.83
# std          2.80               1.83        2.20      0.38
# min          0.00               2.08        0.80      0.00
# 25%          2.00               4.89        2.07      1.00
# 50%          5.00               5.85        3.01      1.00
# 75%          7.00               6.69        4.99      1.00
# max          9.00               9.17        9.89      1.00
#
# [8 rows x 25 columns]

# %% [markdown]
# #### X and Y split

# %%
X =training_merged.drop('ETA',axis=1)
X.head()
# Out:
#                            Origin_lat  Origin_lon  Destination_lat  \
# Timestamp
# 2019-11-19 23:00:08+00:00        3.02       36.75             3.03
# 2019-11-19 23:00:10+00:00        2.97       36.76             3.01
# 2019-11-19 23:00:38+00:00        2.85       36.68             3.05
# 2019-11-19 23:00:44+00:00        2.98       36.76             3.00
# 2019-11-19 23:00:53+00:00        2.86       36.76             3.19
#
#                            Destination_lon  Trip_distance  Speed  \
# Timestamp
# 2019-11-19 23:00:08+00:00            36.77           3898  25.24
# 2019-11-19 23:00:10+00:00            36.73           5861  26.88
# 2019-11-19 23:00:38+00:00            36.78          26065  56.49
# 2019-11-19 23:00:44+00:00            36.78           4943  28.29
# 2019-11-19 23:00:53+00:00            36.72          37492  61.89
#
#                            dewpoint_2m_temperature  \
# Timestamp
# 2019-11-19 23:00:08+00:00                   281.22
# 2019-11-19 23:00:10+00:00                   281.22
# 2019-11-19 23:00:38+00:00                   281.22
# 2019-11-19 23:00:44+00:00                   281.22
# 2019-11-19 23:00:53+00:00                   281.22
#
#                            maximum_2m_air_temperature  \
# Timestamp
# 2019-11-19 23:00:08+00:00                      288.50
# 2019-11-19 23:00:10+00:00                      288.50
# 2019-11-19 23:00:38+00:00                      288.50
# 2019-11-19 23:00:44+00:00                      288.50
# 2019-11-19 23:00:53+00:00                      288.50
#
#                            mean_2m_air_temperature  mean_sea_level_pressure  \
# Timestamp
# 2019-11-19 23:00:08+00:00                   285.20               101,709.28
# 2019-11-19 23:00:10+00:00                   285.20               101,709.28
# 2019-11-19 23:00:38+00:00                   285.20               101,709.28
# 2019-11-19 23:00:44+00:00                   285.20               101,709.28
# 2019-11-19 23:00:53+00:00                   285.20               101,709.28
#
#                            ...  pickup_hour  pickup_minute  pickup_week_hour  \
# Timestamp                  ...
# 2019-11-19 23:00:08+00:00  ...           23              0                47
# 2019-11-19 23:00:10+00:00  ...           23              0                47
# 2019-11-19 23:00:38+00:00  ...           23              0                47
# 2019-11-19 23:00:44+00:00  ...           23              0                47
# 2019-11-19 23:00:53+00:00  ...           23              0                47
#
#                            month  day_of_week  day_of_year  cluster_id  \
# Timestamp
# 2019-11-19 23:00:08+00:00     11            1          323           6
# 2019-11-19 23:00:10+00:00     11            1          323           2
# 2019-11-19 23:00:38+00:00     11            1          323           0
# 2019-11-19 23:00:44+00:00     11            1          323           2
# 2019-11-19 23:00:53+00:00     11            1          323           3
#
#                            temperature_range  wind_speed  rain
# Timestamp
# 2019-11-19 23:00:08+00:00               5.64        3.32     1
# 2019-11-19 23:00:10+00:00               5.64        3.32     1
# 2019-11-19 23:00:38+00:00               5.64        3.32     1
# 2019-11-19 23:00:44+00:00               5.64        3.32     1
# 2019-11-19 23:00:53+00:00               5.64        3.32     1
#
# [5 rows x 24 columns]

# %%
y = training_merged["ETA"]
y.head()
# Out:
# Timestamp
# 2019-11-19 23:00:08+00:00     556
# 2019-11-19 23:00:10+00:00     785
# 2019-11-19 23:00:38+00:00    1661
# 2019-11-19 23:00:44+00:00     629
# 2019-11-19 23:00:53+00:00    2181
# Name: ETA, dtype: int64

# %% [markdown]
# #### Train - Test Split

# %%
81121 * 0.2
# Out:
# 16224.2

# %%
X_train = X.iloc[:-17000]
X_test = X.iloc[-17000:]
X_train.shape,X_test.shape
# Out:
# ((65582, 24), (17000, 24))

# %%
y_train = y.iloc[:-17000]
y_test = y.iloc[-17000:]
y_train.shape,y_test.shape
# Out:
# ((64121,), (17000,))

# %%
from sklearn.datasets import make_regression
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from matplotlib import pyplot

# feature selection
def select_features(X_train, y_train, X_test):
	# configure to select all features
	fs = SelectKBest(score_func=f_regression, k='all')
	# learn relationship from training data
	fs.fit(X_train, y_train)
	# transform train input data
	X_train_fs = fs.transform(X_train)
	# transform test input data
	X_test_fs = fs.transform(X_test)
	return X_train_fs, X_test_fs, fs

# %%
# feature selection
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test)

feature_names = X.columns.tolist()

# Display feature names along with scores
for i, feature_name in enumerate(feature_names):
    print(f'Feature {i}: {feature_name}, Score: {fs.scores_[i]}')
# Out:
# Feature 0: Origin_lat, Score: 13.331522608442985
# Feature 1: Origin_lon, Score: 271.0289559134585
# Feature 2: Destination_lat, Score: 103.20627687229704
# Feature 3: Destination_lon, Score: 420.9408149383884
# Feature 4: Trip_distance, Score: 254059.42818821993
# Feature 5: Speed, Score: 23302.83207504417
# Feature 6: dewpoint_2m_temperature, Score: 62.47005312664121
# Feature 7: mean_2m_air_temperature, Score: 11.573786214931541
# Feature 8: mean_sea_level_pressure, Score: 0.43764497174969197
# Feature 9: total_precipitation, Score: 1.4117292715621508
# Feature 10: pickup_weekday, Score: 14.756851300141399
# Feature 11: pickup_weekofyear, Score: 1.3986459473220902
# Feature 12: pickup_hour, Score: 9.585195990336825
# Feature 13: pickup_minute, Score: 1.5106266929947676
# Feature 14: pickup_week_hour, Score: 19.322206746737894
# Feature 15: month, Score: 1.3774783994254125
# Feature 16: day_of_week, Score: 14.756851300141399
# Feature 17: day_of_year, Score: 0.025941780228715277
# Feature 18: cluster_id, Score: 627.8469524164694
# Feature 19: target_transformed, Score: 5075533.339295116
# Feature 20: temperature_range, Score: 13.24938812099932
# Feature 21: wind_speed, Score: 0.06958563685102717
# Feature 22: rain, Score: 26.98877953535528

# %%
X_train = X_train.drop(columns= ['total_precipitation', 'day_of_year', 'mean_sea_level_pressure'],axis=1)
X_test = X_test.drop(columns= ['total_precipitation', 'day_of_year', 'mean_sea_level_pressure'],axis=1)

# %%
X_train.shape, X_test.shape
# Out:
# ((64121, 20), (17000, 20))

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 64121 entries, 2019-11-19 23:00:08+00:00 to 2019-12-13 05:52:40+00:00
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Origin_lat               64121 non-null  float64
#  1   Origin_lon               64121 non-null  float64
#  2   Destination_lat          64121 non-null  float64
#  3   Destination_lon          64121 non-null  float64
#  4   Trip_distance            64121 non-null  int64
#  5   Speed                    64121 non-null  float64
#  6   dewpoint_2m_temperature  64121 non-null  float64
#  7   mean_2m_air_temperature  64121 non-null  float64
#  8   pickup_weekday           64121 non-null  int32
#  9   pickup_weekofyear        64121 non-null  int32
#  10  pickup_hour              64121 non-null  int32
#  11  pickup_minute            64121 non-null  int32
#  12  pickup_week_hour         64121 non-null  int32
#  13  month                    64121 non-null  int32
#  14  day_of_week              64121 non-null  int32
#  15  cluster_id               64121 non-null  int32
#  16  target_transformed       64121 non-null  float64
#  17  temperature_range        64121 non-null  float64
#  18  wind_speed               64121 non-null  float64
#  19  rain                     64121 non-null  int32
# dtypes: float64(10), int32(9), int64(1)
# memory usage: 8.1 MB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17000 entries, 2019-12-13 05:53:48+00:00 to 2019-12-19 23:59:29+00:00
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Origin_lat               17000 non-null  float64
#  1   Origin_lon               17000 non-null  float64
#  2   Destination_lat          17000 non-null  float64
#  3   Destination_lon          17000 non-null  float64
#  4   Trip_distance            17000 non-null  int64
#  5   Speed                    17000 non-null  float64
#  6   dewpoint_2m_temperature  17000 non-null  float64
#  7   mean_2m_air_temperature  17000 non-null  float64
#  8   pickup_weekday           17000 non-null  int32
#  9   pickup_weekofyear        17000 non-null  int32
#  10  pickup_hour              17000 non-null  int32
#  11  pickup_minute            17000 non-null  int32
#  12  pickup_week_hour         17000 non-null  int32
#  13  month                    17000 non-null  int32
#  14  day_of_week              17000 non-null  int32
#  15  cluster_id               17000 non-null  int32
#  16  target_transformed       17000 non-null  float64
#  17  temperature_range        17000 non-null  float64
#  18  wind_speed               17000 non-null  float64
#  19  rain                     17000 non-null  int32
# dtypes: float64(10), int32(9), int64(1)
# memory usage: 2.1 MB

# %% [markdown]
# #### Pipeline

# %%
input_features =X_train.columns
input_features
# Out:
# Index(['Origin_lat', 'Origin_lon', 'Destination_lat', 'Destination_lon',
#        'Trip_distance', 'Speed', 'dewpoint_2m_temperature',
#        'mean_2m_air_temperature', 'pickup_weekday', 'pickup_weekofyear',
#        'pickup_hour', 'pickup_minute', 'pickup_week_hour', 'month',
#        'day_of_week', 'cluster_id', 'target_transformed', 'temperature_range',
#        'wind_speed', 'rain'],
#       dtype='object')

# %%
#column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('scaler',StandardScaler(),input_features)
        #('log_transformer',FunctionTransformer(np.log1p),input_features)
    ]
)

# %% [markdown]
# ## 4. Machine Learning Modeling
# Here is the section to **build**, **train**, **evaluate** and **compare** the models to each others.

# %% [markdown]
# #### Linear Regression

# %%
# create and fit model
LR = LinearRegression()
pipeline_LR =Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('Linear Regression',LR)
])

pipeline_LR.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('scaler', StandardScaler(),
#                                                   Index(['Origin_lat', 'Origin_lon', 'Destination_lat', 'Destination_lon',
#        'Trip_distance', 'Speed', 'dewpoint_2m_temperature',
#        'mean_2m_air_temperature', 'pickup_weekday', 'pickup_weekofyear',
#        'pickup_hour', 'pickup_minute', 'pickup_week_hour', 'month',
#        'day_of_week', 'cluster_id', 'target_transformed', 'temperature_range',
#        'wind_speed', 'rain'],
#       dtype='object'))])),
#                 ('Linear Regression', LinearRegression())])

# %%
predictions = pipeline_LR.predict(X_test)
predictions[:10]
# Out:
# array([1821.12780671, 1846.34422066, 1511.48709173, 1625.19191072,
#         896.9448523 ,  933.77814612,  959.01429584, 1242.88753759,
#         928.08172682,  933.75568518])

# %%
y_test[:10]
# Out:
# Timestamp
# 2019-12-13 05:53:48+00:00    1835
# 2019-12-13 05:55:08+00:00    1910
# 2019-12-13 05:57:47+00:00    1514
# 2019-12-13 05:59:42+00:00    1645
# 2019-12-13 20:00:07+00:00     872
# 2019-12-13 20:00:11+00:00     901
# 2019-12-13 20:00:13+00:00     943
# 2019-12-13 20:00:17+00:00    1236
# 2019-12-13 20:00:20+00:00     895
# 2019-12-13 20:00:21+00:00     901
# Name: ETA, dtype: int64

# %%
# Predicting and Evaluating the Linear Regression model

mse = mean_squared_error(y_test, predictions)
lr_rmse = np.sqrt(mse)
print(mse)
print(lr_rmse)
# Out:
# 1378.621476153399
# 37.129792298818465

# %% [markdown]
# #### KNN

# %%
# create and fit model

KNN = KNeighborsClassifier()
pipeline_KNN =Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('K-Nearest Neighbors',KNN)
])

pipeline_KNN.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('scaler', StandardScaler(),
#                                                   Index(['Origin_lat', 'Origin_lon', 'Destination_lat', 'Destination_lon',
#        'Trip_distance', 'Speed', 'dewpoint_2m_temperature',
#        'mean_2m_air_temperature', 'pickup_weekday', 'pickup_weekofyear',
#        'pickup_hour', 'pickup_minute', 'pickup_week_hour', 'month',
#        'day_of_week', 'cluster_id', 'target_transformed', 'temperature_range',
#        'wind_speed', 'rain'],
#       dtype='object'))])),
#                 ('K-Nearest Neighbors', KNeighborsClassifier())])

# %%
predictions_knn = pipeline_KNN.predict(X_test)
predictions_knn[:10]
# Out:
# array([1248, 1231, 1186,  817,  783,  533,  709,  773,  533,  533],
#       dtype=int64)

# %%
y_test[:10]
# Out:
# Timestamp
# 2019-12-13 05:53:48+00:00    1835
# 2019-12-13 05:55:08+00:00    1910
# 2019-12-13 05:57:47+00:00    1514
# 2019-12-13 05:59:42+00:00    1645
# 2019-12-13 20:00:07+00:00     872
# 2019-12-13 20:00:11+00:00     901
# 2019-12-13 20:00:13+00:00     943
# 2019-12-13 20:00:17+00:00    1236
# 2019-12-13 20:00:20+00:00     895
# 2019-12-13 20:00:21+00:00     901
# Name: ETA, dtype: int64

# %%
# Predicting and Evaluating the nearest neighbors model

mse = mean_squared_error(y_test, predictions_knn)
knn_rmse = np.sqrt(mse)
print(mse)
print(knn_rmse)
# Out:
# 65899.20382352942
# 256.7084023235886

# %%
knn_score = cross_val_score(pipeline_KNN,X_train,y_train,
                            scoring='neg_mean_squared_error',cv=10)

knn_rmse_score=np.sqrt(-knn_score)

def display_scores(scores):
    print("Score",scores)
    print("Mean",scores.mean())
    print("Standard deviation",scores.std())
    
display_scores(knn_rmse_score)

# %% [markdown]
# #### Decision Tree

# %%
# create and fit model

DT = DecisionTreeRegressor()
pipeline_DT =Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('Decision Tree',DT)
])

pipeline_DT.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('scaler', StandardScaler(),
#                                                   Index(['Origin_lat', 'Origin_lon', 'Destination_lat', 'Destination_lon',
#        'Trip_distance', 'Speed', 'dewpoint_2m_temperature',
#        'mean_2m_air_temperature', 'pickup_weekday', 'pickup_weekofyear',
#        'pickup_hour', 'pickup_minute', 'pickup_week_hour', 'month',
#        'day_of_week', 'cluster_id', 'target_transformed', 'temperature_range',
#        'wind_speed', 'rain'],
#       dtype='object'))])),
#                 ('Decision Tree', DecisionTreeRegressor())])

# %%
predictions_dt = pipeline_DT.predict(X_test)
predictions_dt[:10]
# Out:
# array([1835., 1910., 1514., 1645.,  872.,  901.,  943., 1236.,  895.,
#         901.])

# %%
y_test[:10]
# Out:
# Timestamp
# 2019-12-13 05:53:48+00:00    1835
# 2019-12-13 05:55:08+00:00    1910
# 2019-12-13 05:57:47+00:00    1514
# 2019-12-13 05:59:42+00:00    1645
# 2019-12-13 20:00:07+00:00     872
# 2019-12-13 20:00:11+00:00     901
# 2019-12-13 20:00:13+00:00     943
# 2019-12-13 20:00:17+00:00    1236
# 2019-12-13 20:00:20+00:00     895
# 2019-12-13 20:00:21+00:00     901
# Name: ETA, dtype: int64

# %%
# Predicting and Evaluating the decesion tree model

mse = mean_squared_error(y_test, predictions_dt)
dt_rmse = np.sqrt(mse)
print(mse)
print(dt_rmse)
# Out:
# 0.008352941176470589
# 0.09139442639718567

# %%
dt_scores = cross_val_score(pipeline_DT, X_train, y_train,
                         scoring='neg_mean_squared_error', cv=10)

dtree_rmse_scores = np.sqrt(-dt_scores)

def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

display_scores(dtree_rmse_scores)
# Out:
# Scores: [0.08741127 0.11239468 0.1074284  0.09833295 0.12674238 0.09592443
#  0.11169873 0.0883056  0.11913077 0.09510804]
# Mean: 0.10424772541179647
# Standard deviation: 0.01258941844793003

# %% [markdown]
# #### Random Forest

# %%
# create and fit model

RF = RandomForestRegressor()
pipeline_RF =Pipeline(steps=[
    ('preprocessor',preprocessor),
    ('Random Forest',RF)
])

pipeline_RF.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('scaler', StandardScaler(),
#                                                   Index(['Origin_lat', 'Origin_lon', 'Destination_lat', 'Destination_lon',
#        'Trip_distance', 'Speed', 'dewpoint_2m_temperature',
#        'mean_2m_air_temperature', 'pickup_weekday', 'pickup_weekofyear',
#        'pickup_hour', 'pickup_minute', 'pickup_week_hour', 'month',
#        'day_of_week', 'cluster_id', 'target_transformed', 'temperature_range',
#        'wind_speed', 'rain'],
#       dtype='object'))])),
#                 ('Random Forest', RandomForestRegressor())])

# %%
predictions_rf = pipeline_RF.predict(X_test)
predictions_rf[:10]
# Out:
# array([1835.01, 1910.01, 1514.  , 1645.  ,  872.  ,  901.  ,  943.  ,
#        1236.  ,  895.  ,  901.  ])

# %%
y_test[:10]
# Out:
# Timestamp
# 2019-12-13 05:53:48+00:00    1835
# 2019-12-13 05:55:08+00:00    1910
# 2019-12-13 05:57:47+00:00    1514
# 2019-12-13 05:59:42+00:00    1645
# 2019-12-13 20:00:07+00:00     872
# 2019-12-13 20:00:11+00:00     901
# 2019-12-13 20:00:13+00:00     943
# 2019-12-13 20:00:17+00:00    1236
# 2019-12-13 20:00:20+00:00     895
# 2019-12-13 20:00:21+00:00     901
# Name: ETA, dtype: int64

# %%
# Predicting and Evaluating the random forest model

mse = mean_squared_error(y_test, predictions_rf)
rf_rmse = np.sqrt(mse)
print(mse)
print(rf_rmse)
# Out:
# 0.002687299999999911
# 0.05183917437614059

# %%
rf_scores = cross_val_score(pipeline_RF, X_train, y_train,
                         scoring='neg_mean_squared_error', cv=10)

forest_rmse_scores = np.sqrt(-rf_scores)

def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

display_scores(forest_rmse_scores)
# Out:
# Scores: [0.07776967 0.05608066 0.04186598 0.07382781 0.05726412 0.05541118
#  0.05863798 0.0615573  0.06530401 0.04896559]
# Mean: 0.05966843058062029
# Standard deviation: 0.010162612955028934

# %%
predictions_rf

# %% [markdown]
# #### XGBOOST

# %%
# create and fit model
XGB = XGBRegressor(n_estimators=1000, max_depth=7, eta=0.1, subsample=0.7, colsample_bytree=0.8)
pipeline_XGB =Pipeline(steps=[
    ('preprocessor',preprocessor),G
    ('XGBOOST',XGB)
])

pipeline_XGB.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('scaler', StandardScaler(),
#                                                   Index(['Origin_lat', 'Origin_lon', 'Destination_lat', 'Destination_lon',
#        'Trip_distance', 'Speed', 'dewpoint_2m_temperature',
#        'mean_2m_air_temperature', 'pickup_weekday', 'pickup_weekofyear',
#        'pickup_hour', 'pickup_minute', 'pickup_week_hour', 'month',
#        'day_of_week', 'clust...
#                               eval_metric=None, feature_types=None, gamma=None,
#                               gpu_id=None, grow_policy=None,
#                               importance_type=None,
#                               interaction_constraints=None, learning_rate=None,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=7, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, n_estimators=1000,
#                               n_jobs=None, num_parallel_tree=None,
#                               predictor=None, ...))])

# %%
predictions_xgb = pipeline_XGB.predict(X_test)
predictions_xgb[:10]
# Out:
# array([1833.072  , 1912.5497 , 1513.9406 , 1643.7007 ,  872.62085,
#         901.98206,  940.32916, 1235.7827 ,  895.16864,  902.0742 ],
#       dtype=float32)

# %%
y_test[:10]
# Out:
# Timestamp
# 2019-12-13 05:53:48+00:00    1835
# 2019-12-13 05:55:08+00:00    1910
# 2019-12-13 05:57:47+00:00    1514
# 2019-12-13 05:59:42+00:00    1645
# 2019-12-13 20:00:07+00:00     872
# 2019-12-13 20:00:11+00:00     901
# 2019-12-13 20:00:13+00:00     943
# 2019-12-13 20:00:17+00:00    1236
# 2019-12-13 20:00:20+00:00     895
# 2019-12-13 20:00:21+00:00     901
# Name: ETA, dtype: int64

# %%
# Predicting and Evaluating the xgboost model

mse = mean_squared_error(y_test, predictions_xgb)
xgb_rmse = np.sqrt(mse)
print(mse)
print(xgb_rmse)
# Out:
# 3.8590178863053306
# 1.9644383131840335

# %%
xgb_scores = cross_val_score(pipeline_XGB, X_train, y_train,
                         scoring='neg_mean_squared_error', cv=10)
xgb_rmse_scores = np.sqrt(-xgb_scores)

def display_scores(scores):
    print("Scores:", scores)
    print("Mean:", scores.mean())
    print("Standard deviation:", scores.std())

display_scores(xgb_rmse_scores)
# Out:
# Scores: [2.29790647 3.49095563 3.77183378 3.53940768 3.42224367 3.60928979
#  3.62437972 3.43105818 4.01016297 3.35601922]
# Mean: 3.455325713031718
# Standard deviation: 0.4265922663758243

# %% [markdown]
# ### Evaluation

# %%
# Create a dictionary for accuracy
accuracy_results = {
    'Linear Regression': lr_rmse,
    'RandomForest': rf_rmse,
    'XGB' :xgb_rmse,
    'Decision Tree':dt_rmse,
    'KNN':knn_rmse
}

df = pd.DataFrame(list(accuracy_results.items()), columns=['Model', 'Accuracy'])

# show the result
df_sorted = df.sort_values(by='Accuracy', ascending=True)
df_sorted
# Out:
#                Model  Accuracy
# 1       RandomForest      0.05
# 3      Decision Tree      0.09
# 2                XGB      1.96
# 0  Linear Regression     37.13
# 4                KNN    256.71

# %% [markdown]
# ### Hyperparameter Tuning

# %%
# Check current model parameters
current_params = XGB.get_params()
current_params
# Out:
# {'objective': 'reg:squarederror',
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': 0.8,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'gpu_id': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': 7,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'n_estimators': 1000,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'predictor': None,
#  'random_state': None,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': 0.7,
#  'tree_method': None,
#  'validate_parameters': None,
#  'verbosity': None,
#  'eta': 0.1}

# %%
from sklearn.model_selection import GridSearchCV

params = {
        'min_child_weight': [1, 5, 10],
        'gamma': [0.5, 1, 1.5, 2, 5],
        'subsample': [0.6, 0.8, 1.0],
        'colsample_bytree': [0.6, 0.8, 1.0],
        'max_depth': [4, 8, 12],
        'learning_rate': [0.1, 0.01, 0.05],
        }

XGBOOST = XGBRegressor()

grid_search = GridSearchCV(XGBOOST, params,
                           cv=5, scoring='neg_mean_squared_error',return_train_score=True,
                           verbose=1, n_jobs=-1)

grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 1215 candidates, totalling 6075 fits
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.6, 0.8, 1.0],
#                          'gamma': [0.5, 1, 1.5, 2, 5],
#                          'learning_rate': [0.1, 0.01, 0.05],
#                          'max_depth': [4, 8, 12],
#                          'min_child_weight': [1, 5, 10],
#                          'subsample': [0.6, 0.8, 1.0]},
#              return_train_score=True, scoring='neg_mean_squared_error',
#              verbose=1)

# %%
cvres = grid_search.cv_results_

for mean_score, params in zip(cvres['mean_test_score'], cvres['params']):
    rmse = np.sqrt(np.abs(mean_score))
    print(rmse, params)
# Out:
# 12.935507490441084 {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.6}
# 13.141081215642629 {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.8}
# 13.066830214232212 {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 1.0}
# 12.928892282874134 {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.6}
# 13.170047424538408 {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.8}
# 13.070331596128511 {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 1.0}
# 12.937866894142754 {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.6}
# 13.1400678312653 {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.8}
# 13.070556087785752 {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 1.0}
# 12.066310115361958 {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.6}
# 11.928225139338801 {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.8}
# 12.005738458074275 {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 1.0}
# 12.03036809871213 {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.6}
# 11.820330307365307 {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.8}
# 11.852806629512099 {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 1.0}
# 12.005180423511566 {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.6}
# 11.793845452210231 {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.8}
# 11.74638428919938 {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 1.0}
# 16.553143669477613 {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 0.6}
# 16.484180766891495 {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 0.8}
# 16.691187760390005 {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 1.0}
# 15.565900926031008 {'colsample_bytree': 0.6, 'gamma': 0.5, 'learning_rate': 0.1, 'max_depth': 12, 'min_child_weight': 5, 'subsample': 0.6}
#
{'colsample_bytree': 0.6, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 1.0}
# 12.017582126325799 {'colsample_bytree': 0.6, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.6}
# 11.798531807345306 {'colsample_bytree': 0.6, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.8}
# 11.771688979853238 {'colsample_bytree': 0.6, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 1.0}
# 16.583540045847034 {'colsample_bytree': 0.6, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 0.6}
# 16.479566412409532 {'colsample_bytree': 0.6, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 0.8}
# 16.739747058487332 {'colsample_bytree': 0.6, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 1.0}
# 15.576022475699686 {'colsample_bytree': 0.6, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 12, 'min_child_weight': 5, 'subsample': 0.6}
# 15.568080312667114 {'colsample_bytree': 0.6, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 12, 'min_child_weight': 5, 'subsample': 0.8}
# 15.780769570896018 {'colsample_bytree': 0.6, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 12, 'min_child_weight': 5, 'subsample': 1.0}
# ...
# 190.84945172851064 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.01, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 0.6}
# 190.74596564789783 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.01, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 0.8}
# 190.68226912279283 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.01, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 1.0}
# 190.84944734648582 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.01, 'max_depth': 12, 'min_child_weight': 5, 'subsample': 0.6}
# 190.74596013088345 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.01, 'max_depth': 12, 'min_child_weight': 5, 'subsample': 0.8}
# 190.68226993944648 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.01, 'max_depth': 12, 'min_child_weight': 5, 'subsample': 1.0}
# 190.84972446339447 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.01, 'max_depth': 12, 'min_child_weight': 10, 'subsample': 0.6}
# 190.7460320976505 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.01, 'max_depth': 12, 'min_child_weight': 10, 'subsample': 0.8}
# 190.6822656597886 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.01, 'max_depth': 12, 'min_child_weight': 10, 'subsample': 1.0}
# 5.416180778477956 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.6}
# 5.408806961009753 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.8}
# 5.408985507128025 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 1.0}
# 5.416180778477956 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.6}
# 5.408806961009753 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.8}
# 5.408985507128025 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 1.0}
# 5.416220843918916 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.6}
# 5.408806961009753 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.8}
# 5.408985507128025 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 1.0}
# 5.4106209484896235 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.6}
# 5.389812959780399 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.8}
# 5.360244398503894 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 1.0}
# 5.389057119642487 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.6}
# 5.3752646140692715 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.8}
# 5.371653912748228 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 1.0}
# 5.384835328750158 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.6}
# 5.361271293717363 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.8}
# 5.370707118380778 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 1.0}
# 5.593699926503904 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 0.6}
# 5.5613775221294 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 0.8}
# 5.582448205443595 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 1.0}
# 5.473800443135975 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 12, 'min_child_weight': 5, 'subsample': 0.6}
# 5.455967731384674 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 12, 'min_child_weight': 5, 'subsample': 0.8}
# 5.43845355188726 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 12, 'min_child_weight': 5, 'subsample': 1.0}
# 5.42152538545976 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 12, 'min_child_weight': 10, 'subsample': 0.6}
# 5.416299662721138 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 12, 'min_child_weight': 10, 'subsample': 0.8}
# 5.399573072097755 {'colsample_bytree': 1.0, 'gamma': 2, 'learning_rate': 0.05, 'max_depth': 12, 'min_child_weight': 10, 'subsample': 1.0}
# 4.507577039488455 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.6}
# 4.478094000442427 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.8}
# 4.502339206909913 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 1.0}
# 4.505665116562492 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.6}
# 4.484516598713987 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.8}
# 4.494069374775876 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 1.0}
# 4.515104492440624 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.6}
# 4.489672566924884 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.8}
# 4.48834311869032 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 1.0}
# 4.412349328201869 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.6}
# 4.378033542662906 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.8}
# 4.353516396967829 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 1.0}
# 4.396543296793422 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.6}
# 4.377434055300012 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.8}
# 4.346161982413638 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 1.0}
# 4.363838708400983 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.6}
# 4.373103468830457 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.8}
# 4.3418255193856865 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 1.0}
# 4.522052914914344 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 0.6}
# 4.52091613524382 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 0.8}
# 4.5490286157193465 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 1.0}
# 4.485253349348951 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 12, 'min_child_weight': 5, 'subsample': 0.6}
# 4.460449604858942 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 12, 'min_child_weight': 5, 'subsample': 0.8}
# 4.441142694642742 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 12, 'min_child_weight': 5, 'subsample': 1.0}
# 4.405094839106245 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 12, 'min_child_weight': 10, 'subsample': 0.6}
# 4.43019852051655 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 12, 'min_child_weight': 10, 'subsample': 0.8}
# 4.398022608898979 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.1, 'max_depth': 12, 'min_child_weight': 10, 'subsample': 1.0}
# 191.9147937147066 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.6}
# 191.8607541110615 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.8}
# 191.8342803453478 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 1.0}
# 191.9147937147066 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.6}
# 191.8607541110615 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.8}
# 191.8342803453478 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 1.0}
# 191.9147937147066 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.6}
# 191.8607541110615 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.8}
# 191.8342803453478 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 1.0}
# 190.84840098873983 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.6}
# 190.7465176115961 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.8}
# 190.68211978303282 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 1.0}
# 190.84840098873983 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.6}
# 190.7465176115961 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.8}
# 190.68211978303282 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 1.0}
# 190.84840098873983 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.6}
# 190.7465176115961 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.8}
# 190.68211978303282 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 1.0}
# 190.8497190474675 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 0.6}
# 190.74631373839213 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 0.8}
# 190.68219780029835 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 1.0}
# 190.84971650433937 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 12, 'min_child_weight': 5, 'subsample': 0.6}
# 190.7469568676834 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 12, 'min_child_weight': 5, 'subsample': 0.8}
# 190.6821983797822 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 12, 'min_child_weight': 5, 'subsample': 1.0}
# 190.84971203305201 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 12, 'min_child_weight': 10, 'subsample': 0.6}
# 190.7463748146202 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 12, 'min_child_weight': 10, 'subsample': 0.8}
# 190.68219469290392 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.01, 'max_depth': 12, 'min_child_weight': 10, 'subsample': 1.0}
# 5.416180778477956 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.6}
# 5.408806961009753 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 0.8}
# 5.408985507128025 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 4, 'min_child_weight': 1, 'subsample': 1.0}
# 5.416180778477956 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.6}
# 5.408806961009753 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 0.8}
# 5.408985507128025 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 4, 'min_child_weight': 5, 'subsample': 1.0}
# 5.416220843918916 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.6}
# 5.408806961009753 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 0.8}
# 5.408985507128025 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 4, 'min_child_weight': 10, 'subsample': 1.0}
# 5.4136556462678325 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.6}
# 5.38803542125286 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 0.8}
# 5.362871477570805 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 1, 'subsample': 1.0}
# 5.387793140854864 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.6}
# 5.373170668495852 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 0.8}
# 5.370585977605172 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 5, 'subsample': 1.0}
# 5.379139714400372 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.6}
# 5.365652409529508 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 0.8}
# 5.355312240778085 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 8, 'min_child_weight': 10, 'subsample': 1.0}
# 5.541906945470131 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 0.6}
# 5.550093577785714 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 0.8}
# 5.577740024290859 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 12, 'min_child_weight': 1, 'subsample': 1.0}
# 5.471947069874128 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 12, 'min_child_weight': 5, 'subsample': 0.6}
# 5.466735268004662 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 12, 'min_child_weight': 5, 'subsample': 0.8}
# 5.436140951638469 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 12, 'min_child_weight': 5, 'subsample': 1.0}
# 5.421784210471945 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 12, 'min_child_weight': 10, 'subsample': 0.6}
# 5.415054539591455 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 12, 'min_child_weight': 10, 'subsample': 0.8}
# 5.4158500188803576 {'colsample_bytree': 1.0, 'gamma': 5, 'learning_rate': 0.05, 'max_depth': 12, 'min_child_weight': 10, 'subsample': 1.0}

# %%
grid_search.best_estimator_
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=0.5, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=8, max_leaves=None,
#              min_child_weight=10, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
grid_search.best_params_
# Out:
# {'colsample_bytree': 1.0,
#  'gamma': 0.5,
#  'learning_rate': 0.1,
#  'max_depth': 8,
#  'min_child_weight': 10,
#  'subsample': 1.0}

# %% [markdown]
# ### Save model

# %%
destination = "toolkit"

#create a directory if it doesn't exist
if not os.path.exists(destination):
    os.makedirs(destination)

#Create a dictionary  to store the object and their filename
models ={
    "pipeline":pipeline_XGB
}

#Loop through the model and save them using joblib.dump()
for name,model in models.items():
    file_path =os.path.join(destination,f"{name}.joblib")
    joblib.dump(model,file_path)
